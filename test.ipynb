# %%
import sys
print(sys.executable)
# Out:
# /Users/oz/jupyterlab/crowd-density-risk-map/.venv/bin/python

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt

print("OpenCV:", cv2.__version__)
print("NumPy:", np.__version__)
# Out:
# OpenCV: 4.13.0
# NumPy: 2.4.3
